# %%
# Download the helper library from https://www.twilio.com/docs/python/install
import os
import requests 
from twilio.rest import Client
from twilio_config import TWILIO_ACCOUNT_SSID, TWILIO_AUTH_TOKEN, PHONE_NUMBER, WEATHER_API_KEY
from tqdm import tqdm
import pandas as pd

# %%
city = 'Villavicencio'
url = f'http://api.weatherapi.com/v1/forecast.json?key={WEATHER_API_KEY}&q={city}&days=1&aqi=yes&alerts=no'

# %%
response = requests.get(url).json()

# %%
response
# Out:
# {'location': {'name': 'Villavicencio',
#   'region': 'Meta',
#   'country': 'Colombia',
#   'lat': 4.15,
#   'lon': -73.64,
#   'tz_id': 'America/Bogota',
#   'localtime_epoch': 1677045920,
#   'localtime': '2023-02-22 1:05'},
#  'current': {'last_updated_epoch': 1677045600,
#   'last_updated': '2023-02-22 01:00',
#   'temp_c': 21.6,
#   'temp_f': 70.9,
#   'is_day': 0,
#   'condition': {'text': 'Partly cloudy',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#    'code': 1003},
#   'wind_mph': 2.7,
#   'wind_kph': 4.3,
#   'wind_degree': 323,
#   'wind_dir': 'NW',
#   'pressure_mb': 1013.0,
#   'pressure_in': 29.91,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 54,
#   'cloud': 45,
#   'feelslike_c': 21.6,
#   'feelslike_f': 70.9,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'uv': 1.0,
#   'gust_mph': 5.6,
#   'gust_kph': 9.0,
#   'air_quality': {'co': 280.3999938964844,
#    'no2': 2.799999952316284,
#    'o3': 4.800000190734863,
#    'so2': 0.20000000298023224,
#    'pm2_5': 5.5,
#    'pm10': 6.900000095367432,
#    'us-epa-index': 1,
#    'gb-defra-index': 1}},
#  'forecast': {'forecastday': [{'date': '2023-02-22',
#     'date_epoch': 1677024000,
#     'day': {'maxtemp_c': 31.9,
#      'maxtemp_f': 89.4,
#      'mintemp_c': 19.9,
#      'mintemp_f': 67.8,
#      'avgtemp_c': 25.1,
#      'avgtemp_f': 77.1,
#      'maxwind_mph': 5.1,
#      'maxwind_kph': 8.3,
#      'totalprecip_mm': 0.6,
#      'totalprecip_in': 0.02,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 10.0,
#      'avgvis_miles': 6.0,
#      'avghumidity': 48.0,
#      'daily_will_it_rain': 1,
#      'daily_chance_of_rain': 88,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Patchy rain possible',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#       'code': 1063},
#      'uv': 6.0,
#      'air_quality': {'co': 286.2680029296875,
#       'no2': 2.2279999792575835,
#       'o3': 27.851999950408935,
#       'so2': 0.368000006377697,
#       'pm2_5': 5.696000003814698,
#       'pm10': 6.652000007629394,
#       'us-epa-index': 1,
#       'gb-defra-index': 1}},
#     'astro': {'sunrise': '06:08 AM',
#      'sunset': '06:08 PM',
#      'moonrise': '08:08 AM',
#      'moonset': '08:32 PM',
#      'moon_phase': 'Waxing Crescent',
#      'moon_illumination': '4',
#      'is_moon_up': 1,
#      'is_sun_up': 0},
#     'hour': [{'time_epoch': 1677042000,
#       'time': '2023-02-22 00:00',
#       'temp_c': 22.3,
#       'temp_f': 72.1,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 314,
#       'wind_dir': 'NW',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.93,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 53,
#       'cloud': 47,
#       'feelslike_c': 24.6,
#       'feelslike_f': 76.3,
#       'windchill_c': 22.3,
#       'windchill_f': 72.1,
#       'heatindex_c': 24.6,
#       'heatindex_f': 76.3,
#       'dewpoint_c': 12.4,
#       'dewpoint_f': 54.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.8,
#       'gust_kph': 12.6,
#       'uv': 1.0,
#       'air_quality': {'co': 287.1000061035156,
#        'no2': 3.5999999046325684,
#        'o3': 4.599999904632568,
#        'so2': 0.20000000298023224,
#        'pm2_5': 5.599999904632568,
#        'pm10': 7.300000190734863,
#        'us-epa-index': 1,
#        'gb-defra-index': 1}},
#      {'time_epoch': 1677045600,
#       'time': '2023-02-22 01:00',
#       'temp_c': 21.6,
#       'temp_f': 70.9,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 2.7,
#       'wind_kph': 4.3,
#       'wind_degree': 323,
#       'wind_dir': 'NW',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.91,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 54,
#       'cloud': 45,
#       'feelslike_c': 21.6,
#       'feelslike_f': 70.9,
#       'windchill_c': 21.6,
#       'windchill_f': 70.9,
#       'heatindex_c': 24.4,
#       'heatindex_f': 75.9,
#       'dewpoint_c': 11.9,
#       'dewpoint_f': 53.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.6,
#       'gust_kph': 9.0,
#       'uv': 1.0,
#       'air_quality': {'co': 280.3999938964844,
#        'no2': 2.799999952316284,
#        'o3': 4.800000190734863,
#        'so2': 0.20000000298023224,
#        'pm2_5': 5.5,
#        'pm10': 6.900000095367432,
#        'us-epa-index': 1,
#        'gb-defra-index': 1}},
#      {'time_epoch': 1677049200,
#       'time': '2023-02-22 02:00',
#       'temp_c': 20.7,
#       'temp_f': 69.3,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 2.7,
#       'wind_kph': 4.3,
#       'wind_degree': 325,
#       'wind_dir': 'NW',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.91,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 56,
#       'cloud': 48,
#       'feelslike_c': 20.7,
#       'feelslike_f': 69.3,
#       'windchill_c': 20.7,
#       'windchill_f': 69.3,
#       'heatindex_c': 20.7,
#       'heatindex_f': 69.3,
#       'dewpoint_c': 11.7,
#       'dewpoint_f': 53.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.6,
#       'gust_kph': 9.0,
#       'uv': 1.0,
#       'air_quality': {'co': 270.3999938964844,
#        'no2': 1.899999976158142,
#        'o3': 6.0,
#        'so2': 0.10000000149011612,
#        'pm2_5': 5.199999809265137,
#        'pm10': 6.400000095367432,
#        'us-epa-index': 1,
#        'gb-defra-index': 1}},
#      {'time_epoch': 1677052800,
#       'time': '2023-02-22 03:00',
#       'temp_c': 20.7,
#       'temp_f': 69.3,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 3.1,
#       'wind_kph': 5.0,
#       'wind_degree': 322,
#       'wind_dir': 'NW',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.91,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 57,
#       'cloud': 45,
#       'feelslike_c': 20.7,
#       'feelslike_f': 69.3,
#       'windchill_c': 20.7,
#       'windchill_f': 69.3,
#       'heatindex_c': 20.7,
#       'heatindex_f': 69.3,
#       'dewpoint_c': 12.0,
#       'dewpoint_f': 53.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.5,
#       'gust_kph': 10.4,
#       'uv': 1.0,
#       'air_quality': {'co': 263.70001220703125,
#        'no2': 1.5,
#        'o3': 4.599999904632568,
#        'so2': 0.20000000298023224,
#        'pm2_5': 5.5,
#        'pm10': 6.800000190734863,
#        'us-epa-index': 1,
#        'gb-defra-index': 1}},
#      {'time_epoch': 1677056400,
#       'time': '2023-02-22 04:00',
#       'temp_c': 20.1,
#       'temp_f': 68.2,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 3.6,
#       'wind_kph': 5.8,
#       'wind_degree': 312,
#       'wind_dir': 'NW',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.91,
#       'precip_mm': 0.1,
#       'precip_in': 0.0,
#       'humidity': 60,
#       'cloud': 56,
#       'feelslike_c': 20.1,
#       'feelslike_f': 68.2,
#       'windchill_c': 20.1,
#       'windchill_f': 68.2,
#       'heatindex_c': 20.1,
#       'heatindex_f': 68.2,
#       'dewpoint_c': 12.1,
#       'dewpoint_f': 53.8,
#       'will_it_rain': 1,
#       'chance_of_rain': 76,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.6,
#       'gust_kph': 12.2,
#       'uv': 1.0,
#       'air_quality': {'co': 260.3999938964844,
#        'no2': 1.7000000476837158,
#        'o3': 4.199999809265137,
#        'so2': 0.20000000298023224,
#        'pm2_5': 5.800000190734863,
#        'pm10': 7.199999809265137,
#        'us-epa-index': 1,
#        'gb-defra-index': 1}},
#      {'time_epoch': 1677060000,
#       'time': '2023-02-22 05:00',
#       'temp_c': 20.1,
#       'temp_f': 68.2,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 4.0,
#       'wind_kph': 6.5,
#       'wind_degree': 306,
#       'wind_dir': 'NW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.93,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 61,
#       'cloud': 57,
#       'feelslike_c': 20.1,
#       'feelslike_f': 68.2,
#       'windchill_c': 20.1,
#       'windchill_f': 68.2,
#       'heatindex_c': 20.1,
#       'heatindex_f': 68.2,
#       'dewpoint_c': 12.3,
#       'dewpoint_f': 54.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.5,
#       'gust_kph': 13.7,
#       'uv': 1.0,
#       'air_quality': {'co': 263.70001220703125,
#        'no2': 2.0999999046325684,
#        'o3': 4.099999904632568,
#        'so2': 0.30000001192092896,
#        'pm2_5': 6.0,
#        'pm10': 7.400000095367432,
#        'us-epa-index': 1,
#        'gb-defra-index': 1}},
#      {'time_epoch': 1677063600,
#       'time': '2023-02-22 06:00',
#       'temp_c': 19.9,
#       'temp_f': 67.8,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 303,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 60,
#       'cloud': 56,
#       'feelslike_c': 19.9,
#       'feelslike_f': 67.8,
#       'windchill_c': 19.9,
#       'windchill_f': 67.8,
#       'heatindex_c': 19.9,
#       'heatindex_f': 67.8,
#       'dewpoint_c': 12.0,
#       'dewpoint_f': 53.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.1,
#       'gust_kph': 13.0,
#       'uv': 1.0,
#       'air_quality': {'co': 263.70001220703125,
#        'no2': 2.299999952316284,
#        'o3': 4.099999904632568,
#        'so2': 0.20000000298023224,
#        'pm2_5': 6.199999809265137,
#        'pm10': 7.400000095367432,
#        'us-epa-index': 1,
#        'gb-defra-index': 1}},
#      {'time_epoch': 1677067200,
#       'time': '2023-02-22 07:00',
#       'temp_c': 22.5,
#       'temp_f': 72.5,
#       'is_day': 1,
#       'condition': {'text': 'Light rain shower',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#        'code': 1240},
#       'wind_mph': 3.4,
#       'wind_kph': 5.4,
#       'wind_degree': 300,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.98,
#       'precip_mm': 0.2,
#       'precip_in': 0.01,
#       'humidity': 60,
#       'cloud': 54,
#       'feelslike_c': 24.7,
#       'feelslike_f': 76.5,
#       'windchill_c': 22.5,
#       'windchill_f': 72.5,
#       'heatindex_c': 24.7,
#       'heatindex_f': 76.5,
#       'dewpoint_c': 14.4,
#       'dewpoint_f': 57.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 60,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.4,
#       'gust_kph': 8.6,
#       'uv': 5.0,
#       'air_quality': {'co': 273.70001220703125,
#        'no2': 3.0999999046325684,
#        'o3': 5.300000190734863,
#        'so2': 0.30000001192092896,
#        'pm2_5': 6.300000190734863,
#        'pm10': 7.599999904632568,
#        'us-epa-index': 1,
#        'gb-defra-index': 1}},
#      {'time_epoch': 1677070800,
#       'time': '2023-02-22 08:00',
#       'temp_c': 24.7,
#       'temp_f': 76.5,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 1.6,
#       'wind_kph': 2.5,
#       'wind_degree': 315,
#       'wind_dir': 'NW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 57,
#       'cloud': 49,
#       'feelslike_c': 25.9,
#       'feelslike_f': 78.6,
#       'windchill_c': 24.7,
#       'windchill_f': 76.5,
#       'heatindex_c': 25.9,
#       'heatindex_f': 78.6,
#       'dewpoint_c': 15.7,
#       'dewpoint_f': 60.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 1.8,
#       'gust_kph': 2.9,
#       'uv': 6.0,
#       'air_quality': {'co': 283.70001220703125,
#        'no2': 1.7999999523162842,
#        'o3': 29.299999237060547,
#        'so2': 0.30000001192092896,
#        'pm2_5': 5.800000190734863,
#        'pm10': 6.300000190734863,
#        'us-epa-index': 1,
#        'gb-defra-index': 1}},
#      {'time_epoch': 1677074400,
#       'time': '2023-02-22 09:00',
#       'temp_c': 26.4,
#       'temp_f': 79.5,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 2.2,
#       'wind_kph': 3.6,
#       'wind_degree': 68,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.01,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 50,
#       'cloud': 48,
#       'feelslike_c': 27.0,
#       'feelslike_f': 80.6,
#       'windchill_c': 26.4,
#       'windchill_f': 79.5,
#       'heatindex_c': 27.0,
#       'heatindex_f': 80.6,
#       'dewpoint_c': 15.1,
#       'dewpoint_f': 59.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 2.5,
#       'gust_kph': 4.0,
#       'uv': 7.0,
#       'air_quality': {'co': 300.3999938964844,
#        'no2': 2.0,
#        'o3': 35.79999923706055,
#        'so2': 0.4000000059604645,
#        'pm2_5': 6.599999904632568,
#        'pm10': 7.099999904632568,
#        'us-epa-index': 1,
#        'gb-defra-index': 1}},
#      {'time_epoch': 1677078000,
#       'time': '2023-02-22 10:00',
#       'temp_c': 28.1,
#       'temp_f': 82.6,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 4.7,
#       'wind_kph': 7.6,
#       'wind_degree': 80,
#       'wind_dir': 'E',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.01,
#       'precip_mm': 0.1,
#       'precip_in': 0.0,
#       'humidity': 43,
#       'cloud': 50,
#       'feelslike_c': 28.2,
#       'feelslike_f': 82.8,
#       'windchill_c': 28.1,
#       'windchill_f': 82.6,
#       'heatindex_c': 28.2,
#       'heatindex_f': 82.8,
#       'dewpoint_c': 14.2,
#       'dewpoint_f': 57.6,
#       'will_it_rain': 1,
#       'chance_of_rain': 83,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.4,
#       'gust_kph': 8.6,
#       'uv': 6.0,
#       'air_quality': {'co': 310.3999938964844,
#        'no2': 1.7000000476837158,
#        'o3': 46.5,
#        'so2': 0.5,
#        'pm2_5': 7.199999809265137,
#        'pm10': 7.699999809265137,
#        'us-epa-index': 1,
#        'gb-defra-index': 1}},
#      {'time_epoch': 1677081600,
#       'time': '2023-02-22 11:00',
#       'temp_c': 30.3,
#       'temp_f': 86.5,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 5.1,
#       'wind_kph': 8.3,
#       'wind_degree': 84,
#       'wind_dir': 'E',
#       'pressure_mb': 1016.0,
#       'pressure_in': 29.99,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 40,
#       'cloud': 51,
#       'feelslike_c': 30.4,
#       'feelslike_f': 86.7,
#       'windchill_c': 30.3,
#       'windchill_f': 86.5,
#       'heatindex_c': 30.4,
#       'heatindex_f': 86.7,
#       'dewpoint_c': 15.0,
#       'dewpoint_f': 59.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.8,
#       'gust_kph': 9.4,
#       'uv': 8.0,
#       'air_quality': {'co': 273.70001220703125,
#        'no2': 0.699999988079071,
#        'o3': 56.5,
#        'so2': 0.4000000059604645,
#        'pm2_5': 8.0,
#        'pm10': 8.699999809265137,
#        'us-epa-index': 1,
#        'gb-defra-index': 1}},
#      {'time_epoch': 1677085200,
#       'time': '2023-02-22 12:00',
#       'temp_c': 30.9,
#       'temp_f': 87.6,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 5.1,
#       'wind_kph': 8.3,
#       'wind_degree': 85,
#       'wind_dir': 'E',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.96,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 38,
#       'cloud': 50,
#       'feelslike_c': 31.1,
#       'feelslike_f': 88.0,
#       'windchill_c': 30.9,
#       'windchill_f': 87.6,
#       'heatindex_c': 31.1,
#       'heatindex_f': 88.0,
#       'dewpoint_c': 15.1,
#       'dewpoint_f': 59.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.8,
#       'gust_kph': 9.4,
#       'uv': 8.0,
#       'air_quality': {'co': 263.70001220703125,
#        'no2': 0.4000000059604645,
#        'o3': 58.70000076293945,
#        'so2': 0.4000000059604645,
#        'pm2_5': 8.100000381469727,
#        'pm10': 9.0,
#        'us-epa-index': 1,
#        'gb-defra-index': 1}},
#      {'time_epoch': 1677088800,
#       'time': '2023-02-22 13:00',
#       'temp_c': 30.9,
#       'temp_f': 87.6,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 4.7,
#       'wind_kph': 7.6,
#       'wind_degree': 73,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.91,
#       'precip_mm': 0.1,
#       'precip_in': 0.0,
#       'humidity': 38,
#       'cloud': 79,
#       'feelslike_c': 31.0,
#       'feelslike_f': 87.8,
#       'windchill_c': 30.9,
#       'windchill_f': 87.6,
#       'heatindex_c': 31.0,
#       'heatindex_f': 87.8,
#       'dewpoint_c': 15.0,
#       'dewpoint_f': 59.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 68,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.4,
#       'gust_kph': 8.6,
#       'uv': 7.0,
#       'air_quality': {'co': 263.70001220703125,
#        'no2': 0.5,
#        'o3': 60.099998474121094,
#        'so2': 0.4000000059604645,
#        'pm2_5': 7.699999809265137,
#        'pm10': 8.699999809265137,
#        'us-epa-index': 1,
#        'gb-defra-index': 1}},
#      {'time_epoch': 1677092400,
#       'time': '2023-02-22 14:00',
#       'temp_c': 31.5,
#       'temp_f': 88.7,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 4.0,
#       'wind_kph': 6.5,
#       'wind_degree': 59,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.87,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 37,
#       'cloud': 44,
#       'feelslike_c': 31.6,
#       'feelslike_f': 88.9,
#       'windchill_c': 31.5,
#       'windchill_f': 88.7,
#       'heatindex_c': 31.6,
#       'heatindex_f': 88.9,
#       'dewpoint_c': 14.9,
#       'dewpoint_f': 58.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.7,
#       'gust_kph': 7.6,
#       'uv': 8.0,
#       'air_quality': {'co': 270.3999938964844,
#        'no2': 0.5,
#        'o3': 61.5,
#        'so2': 0.4000000059604645,
#        'pm2_5': 7.599999904632568,
#        'pm10': 8.600000381469727,
#        'us-epa-index': 1,
#        'gb-defra-index': 1}},
#      {'time_epoch': 1677096000,
#       'time': '2023-02-22 15:00',
#       'temp_c': 31.9,
#       'temp_f': 89.4,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 3.6,
#       'wind_kph': 5.8,
#       'wind_degree': 64,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.83,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 35,
#       'cloud': 46,
#       'feelslike_c': 31.9,
#       'feelslike_f': 89.4,
#       'windchill_c': 31.9,
#       'windchill_f': 89.4,
#       'heatindex_c': 31.9,
#       'heatindex_f': 89.4,
#       'dewpoint_c': 14.6,
#       'dewpoint_f': 58.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.0,
#       'gust_kph': 6.5,
#       'uv': 8.0,
#       'air_quality': {'co': 277.0,
#        'no2': 0.6000000238418579,
#        'o3': 62.900001525878906,
#        'so2': 0.4000000059604645,
#        'pm2_5': 7.5,
#        'pm10': 8.5,
#        'us-epa-index': 1,
#        'gb-defra-index': 1}},
#      {'time_epoch': 1677099600,
#       'time': '2023-02-22 16:00',
#       'temp_c': 31.5,
#       'temp_f': 88.7,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 80,
#       'wind_dir': 'E',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.82,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 35,
#       'cloud': 45,
#       'feelslike_c': 31.4,
#       'feelslike_f': 88.5,
#       'windchill_c': 31.5,
#       'windchill_f': 88.7,
#       'heatindex_c': 31.4,
#       'heatindex_f': 88.5,
#       'dewpoint_c': 14.3,
#       'dewpoint_f': 57.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.5,
#       'gust_kph': 7.2,
#       'uv': 8.0,
#       'air_quality': {'co': 283.70001220703125,
#        'no2': 0.800000011920929,
#        'o3': 63.70000076293945,
#        'so2': 0.4000000059604645,
#        'pm2_5': 7.900000095367432,
#        'pm10': 8.899999618530273,
#        'us-epa-index': 1,
#        'gb-defra-index': 1}},
#      {'time_epoch': 1677103200,
#       'time': '2023-02-22 17:00',
#       'temp_c': 30.4,
#       'temp_f': 86.7,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 84,
#       'wind_dir': 'E',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.83,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 38,
#       'cloud': 46,
#       'feelslike_c': 30.3,
#       'feelslike_f': 86.5,
#       'windchill_c': 30.4,
#       'windchill_f': 86.7,
#       'heatindex_c': 30.3,
#       'heatindex_f': 86.5,
#       'dewpoint_c': 14.3,
#       'dewpoint_f': 57.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.5,
#       'gust_kph': 7.2,
#       'uv': 8.0,
#       'air_quality': {'co': 313.79998779296875,
#        'no2': 4.800000190734863,
#        'o3': 41.5,
#        'so2': 0.4000000059604645,
#        'pm2_5': 9.0,
#        'pm10': 10.399999618530273,
#        'us-epa-index': 1,
#        'gb-defra-index': 1}},
#      {'time_epoch': 1677106800,
#       'time': '2023-02-22 18:00',
#       'temp_c': 24.3,
#       'temp_f': 75.7,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 1.8,
#       'wind_kph': 2.9,
#       'wind_degree': 37,
#       'wind_dir': 'NE',
#       'pressure_mb': 1012.0,
#       'pressure_in': 29.87,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 45,
#       'cloud': 46,
#       'feelslike_c': 25.2,
#       'feelslike_f': 77.4,
#       'windchill_c': 24.3,
#       'windchill_f': 75.7,
#       'heatindex_c': 25.2,
#       'heatindex_f': 77.4,
#       'dewpoint_c': 11.5,
#       'dewpoint_f': 52.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.8,
#       'gust_kph': 6.1,
#       'uv': 6.0,
#       'air_quality': {'co': 357.20001220703125,
#        'no2': 9.5,
#        'o3': 21.100000381469727,
#        'so2': 0.4000000059604645,
#        'pm2_5': 10.5,
#        'pm10': 12.300000190734863,
#        'us-epa-index': 1,
#        'gb-defra-index': 1}},
#      {'time_epoch': 1677110400,
#       'time': '2023-02-22 19:00',
#       'temp_c': 23.1,
#       'temp_f': 73.6,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 2.7,
#       'wind_kph': 4.3,
#       'wind_degree': 340,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.9,
#       'precip_mm': 0.1,
#       'precip_in': 0.0,
#       'humidity': 47,
#       'cloud': 78,
#       'feelslike_c': 24.7,
#       'feelslike_f': 76.5,
#       'windchill_c': 23.1,
#       'windchill_f': 73.6,
#       'heatindex_c': 24.7,
#       'heatindex_f': 76.5,
#       'dewpoint_c': 11.1,
#       'dewpoint_f': 52.0,
#       'will_it_rain': 1,
#       'chance_of_rain': 88,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.6,
#       'gust_kph': 9.0,
#       'uv': 1.0,
#       'air_quality': {'co': 360.5,
#        'no2': 9.699999809265137,
#        'o3': 15.399999618530273,
#        'so2': 0.4000000059604645,
#        'pm2_5': 11.100000381469727,
#        'pm10': 13.199999809265137,
#        'us-epa-index': 1,
#        'gb-defra-index': 1}},
#      {'time_epoch': 1677114000,
#       'time': '2023-02-22 20:00',
#       'temp_c': 22.2,
#       'temp_f': 72.0,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 3.4,
#       'wind_kph': 5.4,
#       'wind_degree': 327,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.93,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 48,
#       'cloud': 41,
#       'feelslike_c': 24.4,
#       'feelslike_f': 75.9,
#       'windchill_c': 22.2,
#       'windchill_f': 72.0,
#       'heatindex_c': 24.4,
#       'heatindex_f': 75.9,
#       'dewpoint_c': 10.7,
#       'dewpoint_f': 51.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.9,
#       'gust_kph': 11.2,
#       'uv': 1.0,
#       'air_quality': {'co': 353.79998779296875,
#        'no2': 8.699999809265137,
#        'o3': 16.100000381469727,
#        'so2': 0.5,
#        'pm2_5': 11.600000381469727,
#        'pm10': 13.899999618530273,
#        'us-epa-index': 1,
#        'gb-defra-index': 1}},
#      {'time_epoch': 1677117600,
#       'time': '2023-02-22 21:00',
#       'temp_c': 23.5,
#       'temp_f': 74.3,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 3.6,
#       'wind_kph': 5.8,
#       'wind_degree': 319,
#       'wind_dir': 'NW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.96,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 49,
#       'cloud': 30,
#       'feelslike_c': 24.9,
#       'feelslike_f': 76.8,
#       'windchill_c': 23.5,
#       'windchill_f': 74.3,
#       'heatindex_c': 24.9,
#       'heatindex_f': 76.8,
#       'dewpoint_c': 12.0,
#       'dewpoint_f': 53.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.4,
#       'gust_kph': 11.9,
#       'uv': 1.0,
#       'air_quality': {'co': 347.1000061035156,
#        'no2': 7.5,
#        'o3': 17.399999618530273,
#        'so2': 0.5,
#        'pm2_5': 12.0,
#        'pm10': 14.399999618530273,
#        'us-epa-index': 1,
#        'gb-defra-index': 2}},
#      {'time_epoch': 1677121200,
#       'time': '2023-02-22 22:00',
#       'temp_c': 22.8,
#       'temp_f': 73.0,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 3.4,
#       'wind_kph': 5.4,
#       'wind_degree': 316,
#       'wind_dir': 'NW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.98,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 49,
#       'cloud': 27,
#       'feelslike_c': 24.6,
#       'feelslike_f': 76.3,
#       'windchill_c': 22.8,
#       'windchill_f': 73.0,
#       'heatindex_c': 24.6,
#       'heatindex_f': 76.3,
#       'dewpoint_c': 11.4,
#       'dewpoint_f': 52.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.9,
#       'gust_kph': 11.2,
#       'uv': 1.0,
#       'air_quality': {'co': 333.79998779296875,
#        'no2': 5.699999809265137,
#        'o3': 21.799999237060547,
#        'so2': 0.4000000059604645,
#        'pm2_5': 12.300000190734863,
#        'pm10': 14.5,
#        'us-epa-index': 1,
#        'gb-defra-index': 2}},
#      {'time_epoch': 1677124800,
#       'time': '2023-02-22 23:00',
#       'temp_c': 21.3,
#       'temp_f': 70.3,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.0,
#       'wind_kph': 6.5,
#       'wind_degree': 318,
#       'wind_dir': 'NW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.98,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 50,
#       'cloud': 25,
#       'feelslike_c': 21.3,
#       'feelslike_f': 70.3,
#       'windchill_c': 21.3,
#       'windchill_f': 70.3,
#       'heatindex_c': 24.3,
#       'heatindex_f': 75.7,
#       'dewpoint_c': 10.3,
#       'dewpoint_f': 50.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.5,
#       'gust_kph': 13.7,
#       'uv': 1.0,
#       'air_quality': {'co': 320.3999938964844,
#        'no2': 4.699999809265137,
#        'o3': 34.0,
#        'so2': 0.6000000238418579,
#        'pm2_5': 12.699999809265137,
#        'pm10': 14.800000190734863,
#        'us-epa-index': 1,
#        'gb-defra-index': 2}}]}]}}

# %%
response.keys()
# Out:
# dict_keys(['location', 'current', 'forecast'])

# %%
date = response['location']['localtime'].split()[0]

# %%
response['forecast']['forecastday'][0]['hour'][0]['time'].split()[0]
# Out:
# '2023-02-22'

# %%
response['forecast']['forecastday'][0]['hour'][0]['condition']['text']
# Out:
# 'Partly cloudy'

# %%
weather_list = []

for i in tqdm(range(len(response['forecast']['forecastday'][0]['hour']))):

    place = f"{response['location']['name']}-{response['location']['region']}-{response['location']['country']}"
    date_forecast = response['forecast']['forecastday'][0]['hour'][i]['time'].split()[0]
    hour_forecast = int(response['forecast']['forecastday'][0]['hour'][i]['time'].split()[1].split(':')[0])
    condition = response['forecast']['forecastday'][0]['hour'][i]['condition']['text']
    temp_c = response['forecast']['forecastday'][0]['hour'][i]['temp_c']
    will_rain = response['forecast']['forecastday'][0]['hour'][i]['will_it_rain']
    prob_rain = response['forecast']['forecastday'][0]['hour'][i]['chance_of_rain']

    weather_list.append((place, date_forecast, hour_forecast, condition, temp_c, will_rain, prob_rain))
# Out:
# 100%|██████████| 24/24 [00:00<00:00, 48095.22it/s]

# %%
cols = ['place', 'date_forecast', 'hour_forecast', 'condition', 'temp_c', 'will_rain', 'prob_rain']

# %%
df_weather = pd.DataFrame(weather_list, columns = cols)

# %%
df_weather
# Out:
#                           place date_forecast  hour_forecast  \
# 0   Villavicencio-Meta-Colombia    2023-02-22              0
# 1   Villavicencio-Meta-Colombia    2023-02-22              1
# 2   Villavicencio-Meta-Colombia    2023-02-22              2
# 3   Villavicencio-Meta-Colombia    2023-02-22              3
# 4   Villavicencio-Meta-Colombia    2023-02-22              4
# 5   Villavicencio-Meta-Colombia    2023-02-22              5
# 6   Villavicencio-Meta-Colombia    2023-02-22              6
# 7   Villavicencio-Meta-Colombia    2023-02-22              7
# 8   Villavicencio-Meta-Colombia    2023-02-22              8
# 9   Villavicencio-Meta-Colombia    2023-02-22              9
# 10  Villavicencio-Meta-Colombia    2023-02-22             10
# 11  Villavicencio-Meta-Colombia    2023-02-22             11
# 12  Villavicencio-Meta-Colombia    2023-02-22             12
# 13  Villavicencio-Meta-Colombia    2023-02-22             13
# 14  Villavicencio-Meta-Colombia    2023-02-22             14
# 15  Villavicencio-Meta-Colombia    2023-02-22             15
# 16  Villavicencio-Meta-Colombia    2023-02-22             16
# 17  Villavicencio-Meta-Colombia    2023-02-22             17
# 18  Villavicencio-Meta-Colombia    2023-02-22             18
# 19  Villavicencio-Meta-Colombia    2023-02-22             19
# 20  Villavicencio-Meta-Colombia    2023-02-22             20
# 21  Villavicencio-Meta-Colombia    2023-02-22             21
# 22  Villavicencio-Meta-Colombia    2023-02-22             22
# 23  Villavicencio-Meta-Colombia    2023-02-22             23
#
#                condition  temp_c  will_rain  prob_rain
# 0          Partly cloudy    22.3          0          0
# 1          Partly cloudy    21.6          0          0
# 2          Partly cloudy    20.7          0          0
# 3          Partly cloudy    20.7          0          0
# 4   Patchy rain possible    20.1          1         76
# 5          Partly cloudy    20.1          0          0
# 6          Partly cloudy    19.9          0          0
# 7      Light rain shower    22.5          0         60
# 8          Partly cloudy    24.7          0          0
# 9          Partly cloudy    26.4          0          0
# 10  Patchy rain possible    28.1          1         83
# 11         Partly cloudy    30.3          0          0
# 12         Partly cloudy    30.9          0          0
# 13  Patchy rain possible    30.9          0         68
# 14         Partly cloudy    31.5          0          0
# 15         Partly cloudy    31.9          0          0
# 16         Partly cloudy    31.5          0          0
# 17         Partly cloudy    30.4          0          0
# 18         Partly cloudy    24.3          0          0
# 19  Patchy rain possible    23.1          1         88
# 20         Partly cloudy    22.2          0          0
# 21         Partly cloudy    23.5          0          0
# 22         Partly cloudy    22.8          0          0
# 23                 Clear    21.3          0          0

# %%
df_weather[df_weather['will_rain'] == 1].iloc[0,:]
# Out:
# place            Villavicencio-Meta-Colombia
# date_forecast                     2023-02-22
# hour_forecast                              4
# condition               Patchy rain possible
# temp_c                                  20.1
# will_rain                                  1
# prob_rain                                 76
# Name: 4, dtype: object

# %%
df_weather['prob_rain_%'] = df_weather.prob_rain.apply(lambda x: str(x) + '%')

# %%
df_weather
# Out:
#                           place date_forecast  hour_forecast  \
# 0   Villavicencio-Meta-Colombia    2023-02-22              0
# 1   Villavicencio-Meta-Colombia    2023-02-22              1
# 2   Villavicencio-Meta-Colombia    2023-02-22              2
# 3   Villavicencio-Meta-Colombia    2023-02-22              3
# 4   Villavicencio-Meta-Colombia    2023-02-22              4
# 5   Villavicencio-Meta-Colombia    2023-02-22              5
# 6   Villavicencio-Meta-Colombia    2023-02-22              6
# 7   Villavicencio-Meta-Colombia    2023-02-22              7
# 8   Villavicencio-Meta-Colombia    2023-02-22              8
# 9   Villavicencio-Meta-Colombia    2023-02-22              9
# 10  Villavicencio-Meta-Colombia    2023-02-22             10
# 11  Villavicencio-Meta-Colombia    2023-02-22             11
# 12  Villavicencio-Meta-Colombia    2023-02-22             12
# 13  Villavicencio-Meta-Colombia    2023-02-22             13
# 14  Villavicencio-Meta-Colombia    2023-02-22             14
# 15  Villavicencio-Meta-Colombia    2023-02-22             15
# 16  Villavicencio-Meta-Colombia    2023-02-22             16
# 17  Villavicencio-Meta-Colombia    2023-02-22             17
# 18  Villavicencio-Meta-Colombia    2023-02-22             18
# 19  Villavicencio-Meta-Colombia    2023-02-22             19
# 20  Villavicencio-Meta-Colombia    2023-02-22             20
# 21  Villavicencio-Meta-Colombia    2023-02-22             21
# 22  Villavicencio-Meta-Colombia    2023-02-22             22
# 23  Villavicencio-Meta-Colombia    2023-02-22             23
#
#                condition  temp_c  will_rain  prob_rain prob_rain_%
# 0          Partly cloudy    22.3          0          0          0%
# 1          Partly cloudy    21.6          0          0          0%
# 2          Partly cloudy    20.7          0          0          0%
# 3          Partly cloudy    20.7          0          0          0%
# 4   Patchy rain possible    20.1          1         76         76%
# 5          Partly cloudy    20.1          0          0          0%
# 6          Partly cloudy    19.9          0          0          0%
# 7      Light rain shower    22.5          0         60         60%
# 8          Partly cloudy    24.7          0          0          0%
# 9          Partly cloudy    26.4          0          0          0%
# 10  Patchy rain possible    28.1          1         83         83%
# 11         Partly cloudy    30.3          0          0          0%
# 12         Partly cloudy    30.9          0          0          0%
# 13  Patchy rain possible    30.9          0         68         68%
# 14         Partly cloudy    31.5          0          0          0%
# 15         Partly cloudy    31.9          0          0          0%
# 16         Partly cloudy    31.5          0          0          0%
# 17         Partly cloudy    30.4          0          0          0%
# 18         Partly cloudy    24.3          0          0          0%
# 19  Patchy rain possible    23.1          1         88         88%
# 20         Partly cloudy    22.2          0          0          0%
# 21         Partly cloudy    23.5          0          0          0%
# 22         Partly cloudy    22.8          0          0          0%
# 23                 Clear    21.3          0          0          0%

# %%
df_weather[df_weather['will_rain'] == 1][['hour_forecast', 'condition', 'prob_rain_%']].reset_index(drop = True)
# Out:
#    hour_forecast             condition prob_rain_%
# 0              4  Patchy rain possible         76%
# 1             10  Patchy rain possible         83%
# 2             19  Patchy rain possible         88%

# %%
body_message = f"Take Care!! In {city} at {date} there's a high probability to rain at:\n\n\
{str(df_weather[df_weather['will_rain'] == 1][['hour_forecast', 'condition', 'prob_rain_%']])}"

# %%
body_message
# Out:
# "Take Care!! In Villavicencio at 2023-02-22 there's a high probability to rain at:\n\n    hour_forecast             condition prob_rain_%\n4               4  Patchy rain possible         76%\n10             10  Patchy rain possible         83%\n19             19  Patchy rain possible         88%"

# %%
# Find your Account SID and Auth Token at twilio.com/console
# and set the environment variables. See http://twil.io/secure
account_sid = TWILIO_ACCOUNT_SSID
auth_token = TWILIO_AUTH_TOKEN
client = Client(account_sid, auth_token)

message = client.messages \
    .create(
         body = body_message,
         from_ = PHONE_NUMBER,
         to = '+573502695238'
     )

print(message.sid)
# Out:
# SM7b37563cad0b7f56f4b357b0b40b0da2
